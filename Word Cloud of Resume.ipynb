# %% [markdown]
# <h1 style="text-align:center;">Word Cloud of my Resume</h1>
# <h2 style="text-align:right;">Sthanu Ramakrishnan</h2>

# %% [markdown]
# Reference Code :
# <br>
# https://www.geeksforgeeks.org/working-with-pdf-files-in-python/
# <br>
# https://www.datacamp.com/community/tutorials/wordcloud-python

# %%
import PyPDF2 #Library to access PDF files.
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
# Open the PDF file and save it as a variable
resume = open('resume.pdf', 'rb')

# %% [markdown]
# <p>Syntax : open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)<br>
# 'r'	Open a file for reading. (default)<br>
# 'w'	Open a file for writing. Creates a new file if it does not exist or truncates the file if it exists.<br>
# 'x'	Open a file for exclusive creation. If the file already exists, the operation fails.<br>
# 'a'	Open for appending at the end of the file without truncating it. Creates a new file if it does not exist.<br>
# 't'	Open in text mode. (default)<br>
# 'b'	Open in binary mode.<br>
# '+'	Open a file for updating (reading and writing)</p>

# %%
resume
# Out:
# <_io.BufferedReader name='resume.pdf'>

# %%
# Creating a pdf reader object
pdfReader = PyPDF2.PdfFileReader(resume)

# %%
# Find the Number of pages in the pdfReader object
print(pdfReader.numPages)
# Out:
# 1

# %%
# Create a page object for getting the text of the pdf file
pageObj = pdfReader.getPage(0)

# %%
# Print the text present in the PDF file
resume_text = pageObj.extractText()
resume_text
# Out:
# "Sthanu Ramakrishnan\n \nwww.sthanurk.ml\n \n| \nsramak11@uncc.edu\n \n|\n \n(984) 363\n-\n5691\n \n|\n \n11000 Diploma Dr, Apt H,\n \nCharlotte\n, \nNC 28262\n \n|\n \nlinkedin.com/in/sthanurk\n \n\n \nJunior Data Scientist \n\n \nQuantitative researcher \n\n \nEffective communicator \n\n \nTeam Contributor \n\n \nFlexible \n\n \nInnovative \n\n \nWilling to relocate\n \n\n \nEDUCATION\n \n\n \nMaster's in Data Science and Business Analytic\ns\n \n \n \n         \n \n \n \n \n         \n     \nAug 2018\n \n-\n \nDec\n \n2019\n \nThe \nUniversity of North Carolina at Charlotte\n, NC\n \n \n \n \n \n \n \n \n   \n  \nGPA: 4.0\n \nRelevant Coursework :\n     \n\n \nBusiness Intelligence and Analytics\n     \n\n \nBig Data Ana\nlytics for Competitive Advantage\n     \n\n \nVisual Analytics\n \n\n \nBig Data Design, Storage, and Provenance\n      \n\n \nAdvanced Business Analytics\n     \n\n \nApplied Machine Learning\n     \n\n \nGraduate Econometrics\n \n\n \nBachelor of Engineering in
# ...

# %%
# Close the opened PDF file
resume.close()

# %%
# Removing the '\n' characters
resume_text=resume_text.replace('\n',"")
resume_text
# Out:
# "Sthanu Ramakrishnan www.sthanurk.ml | sramak11@uncc.edu | (984) 363-5691 | 11000 Diploma Dr, Apt H, Charlotte, NC 28262 | linkedin.com/in/sthanurk  Junior Data Scientist  Quantitative researcher  Effective communicator  Team Contributor  Flexible  Innovative  Willing to relocate  EDUCATION  Master's in Data Science and Business Analytics                              Aug 2018 - Dec 2019 The University of North Carolina at Charlotte, NC             GPA: 4.0 Relevant Coursework :      Business Intelligence and Analytics      Big Data Analytics for Competitive Advantage      Visual Analytics  Big Data Design, Storage, and Provenance       Advanced Business Analytics      Applied Machine Learning      Graduate Econometrics  Bachelor of Engineering in Civil Engineering                    Aug 2011 - May 2015 Anna University, Chennai, India              GPA: 4.0 (3rd Rank in Department) PROFESSIONAL EXPERIENCE  Pre-College Student Teacher at Center for STEM Education, UNC Charlotte       Se
# ...

# %%
# Prepare a 800x800 square word cloud 
resume_wordcloud =  WordCloud(width = 800, height = 800, 
                    background_color ='white',
                    min_font_size = 10).generate(resume_text) 
resume_wordcloud

# %%
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(resume_wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
stopwords = set(STOPWORDS)
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
# ...

# %%
# Prepare New Word CLud without Stop Words
resume_wordcloud =  WordCloud(width = 800, height = 800, 
                    background_color ='white',
                    stopwords = stopwords,      
                    min_font_size = 10).generate(resume_text) 
resume_wordcloud

# %%
# plot the WordCloud image without stop words                       
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(resume_wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
irrelevant_words = ['Aug','using','Pvt','July','India']

# %%
# Remove irrelevant Words from the resume_text
for word in irrelevant_words:
    if word in resume_text:
        resume_text=resume_text.replace(word,"")
resume_text
# Out:
# "Sthanu Ramakrishnan www.sthanurk.ml | sramak11@uncc.edu | (984) 363-5691 | 11000 Diploma Dr, Apt H, Charlotte, NC 28262 | linkedin.com/in/sthanurk  Junior Data Scientist  Quantitative researcher  Effective communicator  Team Contributor  Flexible  Innovative  Willing to relocate  EDUCATION  Master's in Data Science and Business Analytics                               2018 - Dec 2019 The University of North Carolina at Charlotte, NC             GPA: 4.0 Relevant Coursework :      Business Intelligence and Analytics      Big Data Analytics for Competitive Advantage      Visual Analytics  Big Data Design, Storage, and Provenance       Advanced Business Analytics      Applied Machine Learning      Graduate Econometrics  Bachelor of Engineering in Civil Engineering                     2011 - May 2015 Anna University, Chennai,               GPA: 4.0 (3rd Rank in Department) PROFESSIONAL EXPERIENCE  Pre-College Student Teacher at Center for STEM Education, UNC Charlotte       Sept 2018 - P
# ...

# %%
# Print the filtered Square word cloud
resume_wordcloud =  WordCloud(width = 600, height = 600, 
                    background_color ='white',
                    stopwords = stopwords,      
                    min_font_size = 10).generate(resume_text) 
resume_wordcloud

# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(resume_wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
# Open the image over which we need to write our Word Cloud
mask = np.array(Image.open("Smiley.png"))

# %%
wordcloud_resume_text = WordCloud(stopwords=stopwords, 
                                  background_color="rgba(255, 255, 255, 0)", #transparent bg
                                  mode="RGBA", 
                                  mask=mask,
                                  min_font_size = 25).generate(resume_text)

# %%
# Disply the word cloud
image_colors = ImageColorGenerator(mask)
plt.figure(figsize=[9,9])
plt.imshow(wordcloud_resume_text.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 1199.5, 1199.5, -0.5)

# %%
# Save the Smiley word cloud as a PNG impage in current folder
wordcloud_resume_text.to_file("resume_wordcloud.png")
